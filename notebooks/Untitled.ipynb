# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../input/train2.csv", index_col = 0 )

# %%
df.head()
# Out:
#    Survived  Pclass  Sex  SibSp  Parch  Fare  Embarked  Deck  Title  port_sex  \
# 0         0       3    0      1      0     7         0     8      1       623
# 1         1       1    1      1      0    71         1     3      3       113
# 2         1       3    1      0      0     7         0     8      2       293
# 3         1       1    1      1      0    53         0     3      3       293
# 4         0       3    0      0      0     8         0     8      1       623
#
#    Age_bin  FamilySize  Ticket_freq
# 0        2         437            1
# 1        7         437            2
# 2        4         790            1
# 3        6         437            2
# 4        6         790            1

# %%
df.to_csv("../input/train_new.csv")

# %%
df2 = pd.read_csv("../input/train_new.csv", index_col = 0 )

# %%
df2.head()
# Out:
#    Survived  Pclass  Sex  SibSp  Parch  Fare  Embarked  Deck  Title  port_sex  \
# 0         0       3    0      1      0     7         0     8      1       623
# 1         1       1    1      1      0    71         1     3      3       113
# 2         1       3    1      0      0     7         0     8      2       293
# 3         1       1    1      1      0    53         0     3      3       293
# 4         0       3    0      0      0     8         0     8      1       623
#
#    Age_bin  FamilySize  Ticket_freq
# 0        2         437            1
# 1        7         437            2
# 2        4         790            1
# 3        6         437            2
# 4        6         790            1

# %%
df3 = pd.read_csv("../input/train_1.csv")

# %%
df3.head()
# Out:
#    Survived  Pclass  Sex  Age  SibSp  Parch  Fare  Embarked  Deck  Title
# 0         0       3    0   22      1      0     7         0     8      1
# 1         1       1    1   38      1      0    71         1     3      3
# 2         1       3    1   26      0      0     7         0     8      2
# 3         1       1    1   35      1      0    53         0     3      3
# 4         0       3    0   35      0      0     8         0     8      1

# %%
df3.iloc[:, 0]
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
train = pd.read_csv("../input/X_train.csv", index_col = 0)

# %%
train
# Out:
#             Pclass  Sex  SibSp  Parch  Fare  Embarked  Deck  Title  port_sex  \
# Unnamed: 0
# 331              1    0      0      0    28         0     3      1       623
# 733              2    0      0      0    13         0     8      1       623
# 382              3    0      0      0     7         0     8      1       623
# 704              3    0      1      0     7         0     8      1       623
# 813              3    1      4      2    31         0     8      2       293
# ...            ...  ...    ...    ...   ...       ...   ...    ...       ...
# 106              3    1      0      0     7         0     8      2       293
# 270              1    0      0      0    31         0     8      1       623
# 860              3    0      2      0    14         0     8      1       623
# 435              1    1      1      2   120         0     2      2       293
# 102              1    0      0      1    77         0     4      1       623
#
# ...

# %%
np.arange(1,len(train.columns),2)
# Out:
# array([ 1,  3,  5,  7,  9, 11])

# %%
df2.head()
# Out:
#    Survived  Pclass  Sex  SibSp  Parch  Fare  Embarked  Deck  Title  port_sex  \
# 0         0       3    0      1      0     7         0     8      1       623
# 1         1       1    1      1      0    71         1     3      3       113
# 2         1       3    1      0      0     7         0     8      2       293
# 3         1       1    1      1      0    53         0     3      3       293
# 4         0       3    0      0      0     8         0     8      1       623
#
#    Age_bin  FamilySize  Ticket_freq
# 0        2         437            1
# 1        7         437            2
# 2        4         790            1
# 3        6         437            2
# 4        6         790            1

# %%
df4 = df2.drop("Parch", axis = 1, inplace = True)

# %%
df4.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-b9e23aa6db1a> in <module>
# ----> 1 df4.head()
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
train3 = df2.copy()

# %%
train3.drop("Parch", axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-a87d0acdf12a> in <module>
# ----> 1 train3.drop("Parch", axis = 1, inplace = True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4168             level=level,
#    4169             inplace=inplace,
# -> 4170             errors=errors,
#    4171         )
#    4172
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
df4 = pd.read_csv("../input/train_new.csv", index_col = 0)

# %%
df4.drop("Parch", axis = 1, inplace = True)

# %%
df4.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'SibSp', 'Fare', 'Embarked', 'Deck',
#        'Title', 'port_sex', 'Age_bin', 'FamilySize', 'Ticket_freq'],
#       dtype='object')

# %%
df4.to_csv("../input/train3.csv")
